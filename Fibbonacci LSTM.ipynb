# %%
import tensorflow as tf

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn import preprocessing
import math

# %%
#For predicting the sequence [1,2,3,4 ...]
#Data = [[[(i+j)/100] for i in range(5)] for j in range(100)]
#Target = [(i+5)/100 for i in range(1,101)]

Data = []
Target = []

a = 1
b = 1
c = a+b
norm_value = 6.624090658521993e+19
log_value = 10
for x in range (0, 100):
    c = a+b
    
    Data.append([[math.log(a)], [math.log(b)], [math.log(c)], [math.log(b+c)]])
    Target.append(math.log(c+b+c))
    
    a = b
    b = c


    
#Normalization


Data
# Out:
# [[[0.0], [0.0], [0.6931471805599453], [1.0986122886681098]],
#  [[0.0], [0.6931471805599453], [1.0986122886681098], [1.6094379124341003]],
#  [[0.6931471805599453],
#   [1.0986122886681098],
#   [1.6094379124341003],
#   [2.0794415416798357]],
#  [[1.0986122886681098],
#   [1.6094379124341003],
#   [2.0794415416798357],
#   [2.5649493574615367]],
#  [[1.6094379124341003],
#   [2.0794415416798357],
#   [2.5649493574615367],
#   [3.044522437723423]],
#  [[2.0794415416798357],
#   [2.5649493574615367],
#   [3.044522437723423],
#   [3.5263605246161616]],
#  [[2.5649493574615367],
#   [3.044522437723423],
#   [3.5263605246161616],
#   [4.007333185232471]],
#  [[3.044522437723423],
#   [3.5263605246161616],
#   [4.007333185232471],
#   [4.48863636973214]],
#  [[3.5263605246161616],
#   [4.007333185232471],
#   [4.48863636973214],
#   [4.969813299576001]],
#  [[4.007333185232471],
#   [4.48863636973214],
#   [4.969813299576001],
#   [5.4510384535657]],
#  [[4.48863636973214],
# ...

# %%
data = np.array(Data, dtype=float)
target = np.array(Target, dtype=float)

# %%
data.shape, target.shape
# Out:
# ((100, 4, 1), (100,))

# %%
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size = 0.2, random_state = 4)

# %%
model = Sequential()
model.add(LSTM((1), batch_input_shape = (None, 4, 1), return_sequences=False))
model.add(Dropout(0.2))




#model.add(LSTM(1, activation='relu'))



model.compile(loss="mean_absolute_error", optimizer="adam", metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_35 (LSTM)               (None, 1)                 12
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 1)                 0
# ...
# Total params: 12
# Trainable params: 12
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train, y_train, epochs=500, validation_data = (x_test, y_test))
# Out:
# Epoch 1/500
# 3/3 [==============================] - 1s 168ms/step - loss: 27.2991 - accuracy: 0.0000e+00 - val_loss: 22.0668 - val_accuracy: 0.0000e+00
# Epoch 2/500
# 3/3 [==============================] - 0s 18ms/step - loss: 27.2995 - accuracy: 0.0000e+00 - val_loss: 22.0633 - val_accuracy: 0.0000e+00
# Epoch 3/500
# 3/3 [==============================] - 0s 21ms/step - loss: 27.3173 - accuracy: 0.0000e+00 - val_loss: 22.0599 - val_accuracy: 0.0000e+00
# Epoch 4/500
# 3/3 [==============================] - 0s 18ms/step - loss: 27.2682 - accuracy: 0.0000e+00 - val_loss: 22.0565 - val_accuracy: 0.0000e+00
# Epoch 5/500
# 3/3 [==============================] - 0s 20ms/step - loss: 27.2508 - accuracy: 0.0000e+00 - val_loss: 22.0532 - val_accuracy: 0.0000e+00
# Epoch 6/500
# 3/3 [==============================] - 0s 20ms/step - loss: 27.2518 - accuracy: 0.0000e+00 - val_loss: 22.0499 - val_accuracy: 0.0000e+00
# Epoch 7/500
# ...
